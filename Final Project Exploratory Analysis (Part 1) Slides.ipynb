# %% [markdown]
# # Comparing Numerical Variables
#
# This first half of the project will focus on comparing the numerical variables to find correlations that can be compared against the categorical and qualitative variables in the dataset

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/Users/6c/Documents/Data Analyst Nanodegree/5th Project'

# %%
df = pd.read_csv('prosperLoanData.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 81 columns):
# ListingKey                             113937 non-null object
# ListingNumber                          113937 non-null int64
# ListingCreationDate                    113937 non-null object
# CreditGrade                            28953 non-null object
# Term                                   113937 non-null int64
# LoanStatus                             113937 non-null object
# ClosedDate                             55089 non-null object
# BorrowerAPR                            113912 non-null float64
# BorrowerRate                           113937 non-null float64
# LenderYield                            113937 non-null float64
# EstimatedEffectiveYield                84853 non-null float64
# EstimatedLoss                          84853 non-null float64
# EstimatedReturn                        84853 non-null float64
# ProsperRating (numeric)                84853 non-null float64
# ProsperRating (Alpha)                  84853 non-null object
# ProsperScore                           84853 non-null float64
# ListingCategory (numeric)              113937 non-null int64
# BorrowerState                          108422 non-null object
# Occupation                             110349 non-null object
# EmploymentStatus                       111682 non-null object
# EmploymentStatusDuration               106312 non-null float64
# IsBorrowerHomeowner                    113937 non-null bool
# CurrentlyInGroup                       113937 non-null bool
# GroupKey                               13341 non-null object
# DateCreditPulled                       113937 non-null object
# CreditScoreRangeLower                  113346 non-null float64
# CreditScoreRangeUpper                  113346 non-null float64
# FirstRecordedCreditLine                113240 non-null object
# CurrentCreditLines                     106333 non-null float64
# OpenCreditLines                        106333 non-null float64
# TotalCreditLinespast7years             113240 non-null float64
# OpenRevolvingAccounts                  113937 non-null int64
# OpenRevolvingMonthlyPayment            113937 non-null float64
# InquiriesLast6Months                   113240 non-null float64
# TotalInquiries                         112778 non-null float64
# CurrentDelinquencies                   113240 non-null float64
# AmountDelinquent                       106315 non-null float64
# DelinquenciesLast7Years                112947 non-null float64
# PublicRecordsLast10Years               113240 non-null float64
# PublicRecordsLast12Months              106333 non-null float64
# RevolvingCreditBalance                 106333 non-null float64
# BankcardUtilization                    106333 non-null float64
# AvailableBankcardCredit                106393 non-null float64
# TotalTrades                            106393 non-null float64
# TradesNeverDelinquent (percentage)     106393 non-null float64
# TradesOpenedLast6Months                106393 non-null float64
# DebtToIncomeRatio                      105383 non-null float64
# IncomeRange                            113937 non-null object
# IncomeVerifiable                       113937 non-null bool
# StatedMonthlyIncome                    113937 non-null float64
# LoanKey                                113937 non-null object
# TotalProsperLoans                      22085 non-null float64
# TotalProsperPaymentsBilled             22085 non-null float64
# OnTimeProsperPayments                  22085 non-null float64
# ProsperPaymentsLessThanOneMonthLate    22085 non-null float64
# ProsperPaymentsOneMonthPlusLate        22085 non-null float64
# ProsperPrincipalBorrowed               22085 non-null float64
# ProsperPrincipalOutstanding            22085 non-null float64
# ScorexChangeAtTimeOfListing            18928 non-null float64
# LoanCurrentDaysDelinquent              113937 non-null int64
# LoanFirstDefaultedCycleNumber          16952 non-null float64
# LoanMonthsSinceOrigination             113937 non-null int64
# LoanNumber                             113937 non-null int64
# LoanOriginalAmount                     113937 non-null int64
# LoanOriginationDate                    113937 non-null object
# LoanOriginationQuarter                 113937 non-null object
# MemberKey                              113937 non-null object
# MonthlyLoanPayment                     113937 non-null float64
# LP_CustomerPayments                    113937 non-null float64
# LP_CustomerPrincipalPayments           113937 non-null float64
# LP_InterestandFees                     113937 non-null float64
# LP_ServiceFees                         113937 non-null float64
# LP_CollectionFees                      113937 non-null float64
# LP_GrossPrincipalLoss                  113937 non-null float64
# LP_NetPrincipalLoss                    113937 non-null float64
# LP_NonPrincipalRecoverypayments        113937 non-null float64
# PercentFunded                          113937 non-null float64
# Recommendations                        113937 non-null int64
# InvestmentFromFriendsCount             113937 non-null int64
# InvestmentFromFriendsAmount            113937 non-null float64
# Investors                              113937 non-null int64
# dtypes: bool(3), float64(50), int64(11), object(17)
# memory usage: 68.1+ MB

# %% [markdown]
# ## First Impression
#
# > because the dataframe has so many columns, the columns must be analyzed, understood and read to find out about the information they contain.

# %%
pd.set_option('display.max_columns', 81)
df.sample(10)
# Out:
#                      ListingKey  ListingNumber            ListingCreationDate  \
# 72750   097935297284972981C01EF         532828  2011-10-15 11:54:51.623000000
# 108836  534F35998566499973A670E        1113175  2014-01-16 06:30:36.610000000
# 107209  F0EC3579435567050137AD1         776132  2013-05-11 22:45:17.167000000
# 26435   9EDE342307992709887F929         351142  2008-06-16 07:14:05.533000000
# 4178    491E3392489993027ED64AC         152961  2007-06-15 21:22:08.320000000
# 17946   513E338121081945524EE40         101513  2007-02-19 17:07:47.307000000
# 102194  26C63543672219078941BD8         577475  2012-04-11 12:27:49.617000000
# 4091    604A3500191940826CB96E8         484089  2010-11-12 19:55:10.547000000
# 39491   3ABA3474886567087307724         445822  2010-02-06 17:56:10.497000000
# 13230   A40533883485991048EF3CD         132234  2007-05-03 13:07:52.567000000
#
#        CreditGrade  Term  LoanStatus           ClosedDate  BorrowerAPR  \
# 72750          NaN    36   Completed  2012-12-27 00:00:00      0.29510
# 108836         NaN    60     Current                  NaN      0.20347
# 107209         NaN    36     Current                  NaN      0.25781
# 26435            C    36   Completed  2011-02-22 00:00:00      0.20149
# 4178            AA    36   Completed  2009-02-06 00:00:00      0.08684
# 17946            C    36   Completed  2009-05-28 00:00:00      0.15211
# 102194         NaN    36     Current                  NaN      0.33553
# 4091           NaN    36   Completed  2013-03-28 00:00:00      0.38723
# 39491          NaN    36   Completed  2012-10-10 00:00:00      0.24939
# 13230            D    36  Chargedoff  2008-01-14 00:00:00      0.29776
#
#         BorrowerRate  LenderYield  EstimatedEffectiveYield  EstimatedLoss  \
# 72750         0.2599       0.2499                  0.24370         0.1120
# 108836        0.1795       0.1695                  0.15767         0.0774
# 107209        0.2199       0.2099                  0.19370         0.0925
# 26435         0.1794       0.1694                      NaN            NaN
# 4178          0.0800       0.0750                      NaN            NaN
# 17946         0.1450       0.1350                      NaN            NaN
# 102194        0.2958       0.2858                  0.27270         0.1470
# 4091          0.3500       0.3400                  0.13690         0.1830
# 39491         0.2148       0.2048                  0.12000         0.0800
# 13230         0.2900       0.2700                      NaN            NaN
#
#         EstimatedReturn  ProsperRating (numeric) ProsperRating (Alpha)  \
# 72750           0.13170                      3.0                     D
# 108836          0.08027                      4.0                     C
# 107209          0.10120                      3.0                     D
# 26435               NaN                      NaN                   NaN
# 4178                NaN                      NaN                   NaN
# 17946               NaN                      NaN                   NaN
# 102194          0.12570                      2.0                     E
# 4091            0.13690                      1.0                    HR
# 39491           0.12000                      4.0                     C
# 13230               NaN                      NaN                   NaN
#
#         ProsperScore  ListingCategory (numeric) BorrowerState  \
# 72750            6.0                          1            WI
# 108836           4.0                          1            NC
# 107209           2.0                         18            CA
# 26435            NaN                          1            AL
# 4178             NaN                          0            OR
# 17946            NaN                          0           NaN
# 102194           6.0                         14            WA
# 4091             4.0                          3            CA
# 39491            8.0                          1            HI
# 13230            NaN                          0            CA
#
#                       Occupation EmploymentStatus  EmploymentStatusDuration  \
# 72750                      Other         Employed                      80.0
# 108836                Nurse (RN)         Employed                     106.0
# 107209                  Attorney         Employed                      68.0
# 26435                      Other        Full-time                      16.0
# 4178                       Other        Full-time                       8.0
# 17946   Administrative Assistant        Full-time                      32.0
# 102194                 Architect         Employed                       0.0
# 4091                     Teacher         Employed                       3.0
# 39491                 Nurse (RN)        Full-time                       6.0
# 13230          Retail Management        Full-time                      44.0
#
#         IsBorrowerHomeowner  CurrentlyInGroup GroupKey  \
# 72750                  True             False      NaN
# 108836                 True             False      NaN
# 107209                 True             False      NaN
# 26435                 False             False      NaN
# 4178                   True             False      NaN
# 17946                 False             False      NaN
# 102194                False             False      NaN
# 4091                  False             False      NaN
# 39491                 False             False      NaN
# 13230                  True              True      NaN
#
#                      DateCreditPulled  CreditScoreRangeLower  \
# 72750             2011-10-15 11:54:47                  680.0
# 108836            2014-01-16 06:30:39                  700.0
# 107209            2013-05-11 22:45:05                  680.0
# 26435   2008-06-07 04:43:32.897000000                  640.0
# 4178    2007-06-15 21:17:22.197000000                  760.0
# 17946   2007-02-18 23:54:11.700000000                  640.0
# 102194            2012-04-11 12:27:44                  680.0
# 4091              2010-11-12 19:55:04                  640.0
# 39491             2010-02-06 17:46:09                  720.0
# 13230   2007-04-20 13:28:55.263000000                  620.0
#
#         CreditScoreRangeUpper FirstRecordedCreditLine  CurrentCreditLines  \
# 72750                   699.0     2003-03-24 00:00:00                12.0
# 108836                  719.0     2001-08-16 00:00:00                 7.0
# 107209                  699.0     1972-10-01 00:00:00                20.0
# 26435                   659.0     1994-10-01 00:00:00                 4.0
# 4178                    779.0     1997-03-11 00:00:00                12.0
# 17946                   659.0     2000-02-22 00:00:00                14.0
# 102194                  699.0     1997-10-23 00:00:00                 5.0
# 4091                    659.0     1997-06-01 00:00:00                10.0
# 39491                   739.0     1992-10-15 00:00:00                 7.0
# 13230                   639.0     1999-10-17 00:00:00                 5.0
#
#         OpenCreditLines  TotalCreditLinespast7years  OpenRevolvingAccounts  \
# 72750              11.0                        25.0                      9
# 108836              3.0                        17.0                      2
# 107209             17.0                        56.0                     18
# 26435               3.0                        22.0                      2
# 4178               11.0                        13.0                      8
# 17946               6.0                        30.0                      5
# 102194              5.0                        44.0                      3
# 4091                8.0                        29.0                      6
# 39491               6.0                        36.0                      4
# 13230               5.0                        12.0                      2
#
#         OpenRevolvingMonthlyPayment  InquiriesLast6Months  TotalInquiries  \
# 72750                         610.0                   0.0             2.0
# 108836                       1698.0                   3.0             7.0
# 107209                       2165.0                   3.0             7.0
# 26435                         195.0                   0.0             3.0
# 4178                          253.0                   1.0             1.0
# 17946                         254.0                   2.0             6.0
# 102194                        128.0                   0.0             2.0
# 4091                          178.0                   2.0             6.0
# 39491                          47.0                   0.0             1.0
# 13230                          15.0                  12.0            22.0
#
#         CurrentDelinquencies  AmountDelinquent  DelinquenciesLast7Years  \
# 72750                    0.0               0.0                      0.0
# 108836                   0.0               0.0                      0.0
# 107209                   0.0               0.0                      0.0
# 26435                    0.0               0.0                      0.0
# 4178                     0.0               0.0                      0.0
# 17946                    0.0               0.0                      0.0
# 102194                   0.0               0.0                      0.0
# 4091                     0.0               0.0                      0.0
# 39491                    0.0               0.0                      3.0
# 13230                    2.0             502.0                      1.0
#
#         PublicRecordsLast10Years  PublicRecordsLast12Months  \
# 72750                        1.0                        0.0
# 108836                       0.0                        0.0
# 107209                       0.0                        0.0
# 26435                        1.0                        0.0
# 4178                         0.0                        0.0
# 17946                        0.0                        0.0
# 102194                       0.0                        0.0
# 4091                         0.0                        0.0
# 39491                        1.0                        0.0
# 13230                        0.0                        0.0
#
#         RevolvingCreditBalance  BankcardUtilization  AvailableBankcardCredit  \
# 72750                  16673.0                 0.70                   7027.0
# 108836                337621.0                 0.09                    454.0
# 107209                166257.0                 0.84                  30181.0
# 26435                   5283.0                 0.99                    133.0
# 4178                    7186.0                 0.12                  44209.0
# 17946                   7816.0                 0.97                    405.0
# 102194                  3047.0                 0.81                    529.0
# 4091                    6216.0                 0.96                    138.0
# 39491                    885.0                 0.91                     44.0
# 13230                    355.0                 0.84                     64.0
#
#         TotalTrades  TradesNeverDelinquent (percentage)  \
# 72750          25.0                                1.00
# 108836         15.0                                0.80
# 107209         42.0                                0.97
# 26435          20.0                                1.00
# 4178           12.0                                1.00
# 17946          21.0                                0.90
# 102194          7.0                                0.85
# 4091           25.0                                0.88
# 39491          20.0                                0.90
# 13230          10.0                                0.63
#
#         TradesOpenedLast6Months  DebtToIncomeRatio     IncomeRange  \
# 72750                       0.0               0.54  $25,000-49,999
# 108836                      1.0               0.25  $75,000-99,999
# 107209                      0.0               0.14       $100,000+
# 26435                       0.0               0.25  $25,000-49,999
# 4178                        1.0               0.12  $50,000-74,999
# 17946                       0.0               0.19  $25,000-49,999
# 102194                      0.0               0.25  $25,000-49,999
# 4091                        0.0               0.21  $50,000-74,999
# 39491                       0.0               2.28       $1-24,999
# 13230                       2.0               0.37  $25,000-49,999
#
#         IncomeVerifiable  StatedMonthlyIncome                  LoanKey  \
# 72750               True          2500.000000  D2FC3636101612183A3BBA5
# 108836              True          8000.000000  29A23704495014195ABE235
# 107209              True         23250.000000  81BB36828545459057FC8C9
# 26435               True          2941.666667  BF353425280387362A717C7
# 4178                True          4583.333333  CD983393997999869856D6E
# 17946               True          2916.666667  090533819546745690648AA
# 102194              True          3000.000000  37303647224180961661523
# 4091                True          4166.666667  18C43605553184534667D9C
# 39491               True           200.000000  FA31358064137529011A126
# 13230               True          3125.000000  199A3389149714984CEA380
#
#         TotalProsperLoans  TotalProsperPaymentsBilled  OnTimeProsperPayments  \
# 72750                 NaN                         NaN                    NaN
# 108836                1.0                         9.0                    9.0
# 107209                NaN                         NaN                    NaN
# 26435                 NaN                         NaN                    NaN
# 4178                  NaN                         NaN                    NaN
# 17946                 NaN                         NaN                    NaN
# 102194                NaN                         NaN                    NaN
# 4091                  NaN                         NaN                    NaN
# 39491                 NaN                         NaN                    NaN
# 13230                 NaN                         NaN                    NaN
#
#         ProsperPaymentsLessThanOneMonthLate  ProsperPaymentsOneMonthPlusLate  \
# 72750                                   NaN                              NaN
# 108836                                  0.0                              0.0
# 107209                                  NaN                              NaN
# 26435                                   NaN                              NaN
# 4178                                    NaN                              NaN
# 17946                                   NaN                              NaN
# 102194                                  NaN                              NaN
# 4091                                    NaN                              NaN
# 39491                                   NaN                              NaN
# 13230                                   NaN                              NaN
#
#         ProsperPrincipalBorrowed  ProsperPrincipalOutstanding  \
# 72750                        NaN                          NaN
# 108836                    4000.0                          0.0
# 107209                       NaN                          NaN
# 26435                        NaN                          NaN
# 4178                         NaN                          NaN
# 17946                        NaN                          NaN
# 102194                       NaN                          NaN
# 4091                         NaN                          NaN
# 39491                        NaN                          NaN
# 13230                        NaN                          NaN
#
#         ScorexChangeAtTimeOfListing  LoanCurrentDaysDelinquent  \
# 72750                           NaN                          0
# 108836                          NaN                          0
# 107209                          NaN                          0
# 26435                           NaN                          0
# 4178                            NaN                          0
# 17946                           NaN                          0
# 102194                          NaN                          0
# 4091                            NaN                          0
# 39491                           NaN                          0
# 13230                           NaN                       2368
#
#         LoanFirstDefaultedCycleNumber  LoanMonthsSinceOrigination  LoanNumber  \
# 72750                             NaN                          28       56222
# 108836                            NaN                           2      127260
# 107209                            NaN                          10       90423
# 26435                             NaN                          69       33317
# 4178                              NaN                          80       17033
# 17946                             NaN                          85        7913
# 102194                            NaN                          23       63664
# 4091                              NaN                          40       45607
# 39491                             NaN                          49       40969
# 13230                             8.0                          82       14969
#
#         LoanOriginalAmount  LoanOriginationDate LoanOriginationQuarter  \
# 72750                 8000  2011-11-17 00:00:00                Q4 2011
# 108836               13000  2014-01-22 00:00:00                Q1 2014
# 107209               15000  2013-05-17 00:00:00                Q2 2013
# 26435                 6500  2008-06-24 00:00:00                Q2 2008
# 4178                  2500  2007-07-19 00:00:00                Q3 2007
# 17946                 5000  2007-02-28 00:00:00                Q1 2007
# 102194                4000  2012-04-16 00:00:00                Q2 2012
# 4091                  2500  2010-11-30 00:00:00                Q4 2010
# 39491                 1100  2010-02-23 00:00:00                Q1 2010
# 13230                12650  2007-05-15 00:00:00                Q2 2007
#
#                       MemberKey  MonthlyLoanPayment  LP_CustomerPayments  \
# 72750   24F735286133150086BED4E              322.28             10023.65
# 108836  FEA93562036377101932940              329.76               329.76
# 107209  75A03577754993985A94684              572.78              5155.02
# 26435   88203418398181371AFC593              234.79              8294.44
# 4178    23A43390366534930E86CCF               78.34              2677.46
# 17946   B881338160405230580C2F6              172.10              6078.96
# 102194  D30D354374010839816CD19              168.89              3715.58
# 4091    DEEB35002354219363EA23A              113.09              3982.80
# 39491   D0FF3474894604971955A31               41.71              1491.33
# 13230   EB2433865591507060B9DDB              530.11              1559.01
#
#         LP_CustomerPrincipalPayments  LP_InterestandFees  LP_ServiceFees  \
# 72750                        7999.99             2023.66          -77.88
# 108836                        131.57              198.19          -11.04
# 107209                       2866.51             2288.51         -104.06
# 26435                        6499.99             1794.45         -100.05
# 4178                         2500.00              177.46          -11.07
# 17946                        5000.00             1078.96          -74.41
# 102194                       2016.11             1699.47          -57.46
# 4091                         2500.00             1482.80          -42.36
# 39491                        1099.66              391.67          -18.25
# 13230                         682.02              876.99          -31.32
#
#         LP_CollectionFees  LP_GrossPrincipalLoss  LP_NetPrincipalLoss  \
# 72750                 0.0                   0.00                 0.00
# 108836                0.0                   0.00                 0.00
# 107209                0.0                   0.00                 0.00
# 26435                 0.0                   0.00                 0.00
# 4178                  0.0                   0.00                 0.00
# 17946                 0.0                   0.00                 0.00
# 102194                0.0                   0.00                 0.00
# 4091                  0.0                   0.00                 0.00
# 39491                 0.0                   0.00                 0.00
# 13230                 0.0               11967.98             11967.98
#
#         LP_NonPrincipalRecoverypayments  PercentFunded  Recommendations  \
# 72750                               0.0            1.0                0
# 108836                              0.0            1.0                0
# 107209                              0.0            1.0                0
# 26435                               0.0            1.0                0
# 4178                                0.0            1.0                0
# 17946                               0.0            1.0                0
# 102194                              0.0            1.0                0
# 4091                                0.0            1.0                0
# 39491                               0.0            1.0                0
# 13230                               0.0            1.0                0
#
#         InvestmentFromFriendsCount  InvestmentFromFriendsAmount  Investors
# 72750                            0                          0.0         18
# 108836                           0                          0.0         26
# 107209                           0                          0.0        267
# 26435                            0                          0.0        116
# 4178                             0                          0.0         95
# 17946                            0                          0.0        148
# 102194                           0                          0.0          2
# 4091                             0                          0.0         84
# 39491                            0                          0.0         52
# 13230                            0                          0.0        125

# %% [markdown]
# Columns of Intrest:
# 1. Term
# 2. BorrowerAPR
# 3. BorrowerRate
# 4. LenderYield
# 5. BorrowerState
# 6. Occuptaion
# 7. IsBorrowerHomeowner
# 8. CreditScoreRangeLower
# 9. CreditScoreRangeUpper
# 10. CurrentCreditLines
# 11. OpenCreditLines
# 12. TotalCreditLinespast7years
# 13. CurrentDelinquencies
# 14. AmountDelinquent
# 15. DelinquenciesLast7Years
# 16. RevolvingCreditBalance
# 17. AvailableBankcardCredit
# 18. TradesNeverDelinquent (percentage)
# 19. DebtToIncomeRatio
# 20. IncomeRange
# 21. StatedMonthlyIncome
# 22. ProsperPrincipalBorrowed
# 23. LoanOriginalAmount
# 24. MonthlyLoanPayment
# 25. LP_CustomerPayments
# 26. LP_CustomerPrincipalPayments
# 27. LP_InterestandFees
# 28. Investors

# %% [markdown]
# # Feature Engineering
#
# > Creating new columns as needed for data analysis

# %%
df['Credit_Score_Avg'] = (df['CreditScoreRangeLower'] + df['CreditScoreRangeUpper']) / 2 
df['Annual_Income'] = df['StatedMonthlyIncome'] * 12

# %%
Interesting_columns = ['Term', 'LoanStatus', 'BorrowerAPR', 'BorrowerRate', 'LenderYield', 'BorrowerState', 'Occupation', 'IsBorrowerHomeowner',
                       'CreditScoreRangeLower', 'CreditScoreRangeUpper', 'CurrentCreditLines', 'OpenCreditLines', 'TotalCreditLinespast7years',
                       'CurrentDelinquencies', 'AmountDelinquent', 'DelinquenciesLast7Years', 'RevolvingCreditBalance', 'AvailableBankcardCredit', 
                       'TradesNeverDelinquent (percentage)', 'DebtToIncomeRatio', 'IncomeRange', 'StatedMonthlyIncome', 'ProsperPrincipalBorrowed', 
                       'LoanOriginalAmount', 'MonthlyLoanPayment', 'LP_CustomerPayments', 'LP_CustomerPrincipalPayments', 'LP_InterestandFees', 'Investors',
                        'Credit_Score_Avg', 'Annual_Income']

# %%
status_test = df[Interesting_columns]

# %%
df = status_test

# %%
loan_stats = df.describe()
loan_stats
#df.nunique()
# Out:
#                 Term    BorrowerAPR   BorrowerRate    LenderYield  \
# count  113937.000000  113912.000000  113937.000000  113937.000000
# mean       40.830248       0.218828       0.192764       0.182701
# std        10.436212       0.080364       0.074818       0.074516
# min        12.000000       0.006530       0.000000      -0.010000
# 25%        36.000000       0.156290       0.134000       0.124200
# 50%        36.000000       0.209760       0.184000       0.173000
# 75%        36.000000       0.283810       0.250000       0.240000
# max        60.000000       0.512290       0.497500       0.492500
#
#        CreditScoreRangeLower  CreditScoreRangeUpper  CurrentCreditLines  \
# count          113346.000000          113346.000000       106333.000000
# mean              685.567731             704.567731           10.317192
# std                66.458275              66.458275            5.457866
# min                 0.000000              19.000000            0.000000
# 25%               660.000000             679.000000            7.000000
# 50%               680.000000             699.000000           10.000000
# 75%               720.000000             739.000000           13.000000
# max               880.000000             899.000000           59.000000
#
#        OpenCreditLines  TotalCreditLinespast7years  CurrentDelinquencies  \
# count    106333.000000               113240.000000         113240.000000
# mean          9.260164                   26.754539              0.592052
# std           5.022644                   13.637871              1.978707
# min           0.000000                    2.000000              0.000000
# 25%           6.000000                   17.000000              0.000000
# 50%           9.000000                   25.000000              0.000000
# 75%          12.000000                   35.000000              0.000000
# max          54.000000                  136.000000             83.000000
#
#        AmountDelinquent  DelinquenciesLast7Years  RevolvingCreditBalance  \
# count     106315.000000            112947.000000            1.063330e+05
# mean         984.507059                 4.154984            1.759871e+04
# std         7158.270157                10.160216            3.293640e+04
# min            0.000000                 0.000000            0.000000e+00
# 25%            0.000000                 0.000000            3.121000e+03
# 50%            0.000000                 0.000000            8.549000e+03
# 75%            0.000000                 3.000000            1.952100e+04
# max       463881.000000                99.000000            1.435667e+06
#
#        AvailableBankcardCredit  TradesNeverDelinquent (percentage)  \
# count            106393.000000                       106393.000000
# mean              11210.225447                            0.885897
# std               19818.361309                            0.148179
# min                   0.000000                            0.000000
# 25%                 880.000000                            0.820000
# 50%                4100.000000                            0.940000
# 75%               13180.000000                            1.000000
# max              646285.000000                            1.000000
#
#        DebtToIncomeRatio  StatedMonthlyIncome  ProsperPrincipalBorrowed  \
# count      105383.000000         1.139370e+05              22085.000000
# mean            0.275947         5.608026e+03               8472.311961
# std             0.551759         7.478497e+03               7395.507650
# min             0.000000         0.000000e+00                  0.000000
# 25%             0.140000         3.200333e+03               3500.000000
# 50%             0.220000         4.666667e+03               6000.000000
# 75%             0.320000         6.825000e+03              11000.000000
# max            10.010000         1.750003e+06              72499.000000
#
#        LoanOriginalAmount  MonthlyLoanPayment  LP_CustomerPayments  \
# count        113937.00000       113937.000000        113937.000000
# mean           8337.01385          272.475783          4183.079489
# std            6245.80058          192.697812          4790.907234
# min            1000.00000            0.000000            -2.349900
# 25%            4000.00000          131.620000          1005.760000
# 50%            6500.00000          217.740000          2583.830000
# 75%           12000.00000          371.580000          5548.400000
# max           35000.00000         2251.510000         40702.390000
#
#        LP_CustomerPrincipalPayments  LP_InterestandFees      Investors  \
# count                 113937.000000       113937.000000  113937.000000
# mean                    3105.536588         1077.542901      80.475228
# std                     4069.527670         1183.414168     103.239020
# min                        0.000000           -2.349900       1.000000
# 25%                      500.890000          274.870000       2.000000
# 50%                     1587.500000          700.840100      44.000000
# 75%                     4000.000000         1458.540000     115.000000
# max                    35000.000000        15617.030000    1189.000000
#
#        Credit_Score_Avg  Annual_Income
# count     113346.000000   1.139370e+05
# mean         695.067731   6.729631e+04
# std           66.458275   8.974197e+04
# min            9.500000   0.000000e+00
# 25%          669.500000   3.840400e+04
# 50%          689.500000   5.600000e+04
# 75%          729.500000   8.190000e+04
# max          889.500000   2.100004e+07

# %% [markdown]
# ## Univariate Exploration
#
# This exploration will start with the term of the loans.
# > It turns out that there are only 3 different terms, 12, 36 and 60 month loans

# %%
binsize = 2
bins = np.arange(12, 60+ binsize, binsize)
plt.hist(data = df, x = 'Term', bins = bins);
plt.xlabel('Length of Loan (Months)');
plt.ylabel('Number of Loans');

# %%
df.Term.value_counts()
# Out:
# 36    87778
# 60    24545
# 12     1614
# Name: Term, dtype: int64

# %% [markdown]
# The next item on the list is a distribution of the Borrower's APR; or: how much usury the bank is charging.
# > The linear plot works for the distribution, while the log plot does not add any additional insights into Prosper Loan's APR information
#
# >Becuase APR includes information such as the rate and other fees, the next column, BorrowerRate, will not be analysed

# %%
binsize = 0.01
bins = np.arange(0.006, 0.52+ binsize, binsize)
plt.hist(data = df, x = 'BorrowerAPR', bins = bins);
plt.xlabel('APR');
plt.ylabel('Number of Loans');

# %%
logbinsize = 0.01
logbins = 10** np.arange( -1.4, -0.301 +logbinsize, logbinsize)

plt.hist(data = df, x = 'BorrowerAPR', bins = logbins);
plt.xscale('log');
plt.xticks([(1e-1), 0.75], [0.37, 0.75]);

# %%
def histogram_EDA(column):
    category = loan_stats[column]
    mini = category.loc['min']
    maxi = category.loc['max']
    
    if category.loc['std'] >= 1:
        numberofbins = 10
    elif category.loc['std'] < 1 and category.loc['std'] >= 0.75:
        numberofbins = 20
    elif category.loc['std'] < 0.75:
        numberofbins = 30
    
    #number of unique values: 0-10: 5
    #number of values: 10-50: 10
    #number of values:
    
    bin_size = round((maxi - mini)/ numberofbins, 3)
    bins = np.arange(mini, maxi + bin_size, bin_size)
    plt.hist(data = df, x = column, bins = bins);
    
    #calculate the number of bins based on nunique

# %% [markdown]
# ## You Choose the Column
# Input which column name you want to see a histogram for and it will be plotted

# %%
print('Input the name of the column where you want to create a histogram: ')
col_name = input()
histogram_EDA(col_name)
# Out:
# Input the name of the column where you want to create a histogram:
# Annual_Income

# %% [markdown]
# ## Revolving Credit Balance
#
# Because of the tail in the data, a Logarithmic scale was used to better show the variance in the column. The data appears to have a peak of 10^4 or a $10,000 revolving credit balance, which is the amount of the loan left unpaid after the billing cycle is complete.

# %%
binsize = 500
bins = np.arange(0, 5e4 + binsize, binsize)
plt.hist(data = df, x = 'RevolvingCreditBalance', bins = bins);

# %%
logbinsize = 0.1
logbins = 10** np.arange(1, 6 + logbinsize, logbinsize)

plt.hist(data = df, x = 'RevolvingCreditBalance', bins = logbins);
plt.xscale('log');
plt.xticks([1e1, 1e2, 1e3, 1e4, 1e5, 1e6],[10, 100, 1000, 10000, 100000, '1000000']);
plt.xlabel("Amount of debt unpaid after billing cycle (USD)");
plt.title("Revolving Credit Balance");
plt.ylabel("Number in Bin");

# %% [markdown]
# ## Credit Score Range
#
# Created a column which calculated the the average credit score from the upper and lower credit score ranges of the different data sets.
#
# There is a single datapoint in the credit score range which is 9.5, which is a huge outlier and should be removed.

# %%
df['Credit_Score_Avg'] = (df['CreditScoreRangeLower'] + df['CreditScoreRangeUpper']) / 2 
testdf = df['Credit_Score_Avg'] >= 10
testdf.describe()
# Out:
# count     113937
# unique         2
# top         True
# freq      113213
# Name: Credit_Score_Avg, dtype: object

# %%
binsize = 20
bins = np.arange(400, 890 + binsize, binsize)
plt.hist(data = df, x = 'Credit_Score_Avg', bins = bins);
plt.xlabel('Average Credit Score');
plt.title('Credit Score Distribution');

# %%
loan_stats
# Out:
#                 Term    BorrowerAPR   BorrowerRate    LenderYield  \
# count  113937.000000  113912.000000  113937.000000  113937.000000
# mean       40.830248       0.218828       0.192764       0.182701
# std        10.436212       0.080364       0.074818       0.074516
# min        12.000000       0.006530       0.000000      -0.010000
# 25%        36.000000       0.156290       0.134000       0.124200
# 50%        36.000000       0.209760       0.184000       0.173000
# 75%        36.000000       0.283810       0.250000       0.240000
# max        60.000000       0.512290       0.497500       0.492500
#
#        CreditScoreRangeLower  CreditScoreRangeUpper  CurrentCreditLines  \
# count          113346.000000          113346.000000       106333.000000
# mean              685.567731             704.567731           10.317192
# std                66.458275              66.458275            5.457866
# min                 0.000000              19.000000            0.000000
# 25%               660.000000             679.000000            7.000000
# 50%               680.000000             699.000000           10.000000
# 75%               720.000000             739.000000           13.000000
# max               880.000000             899.000000           59.000000
#
#        OpenCreditLines  TotalCreditLinespast7years  CurrentDelinquencies  \
# count    106333.000000               113240.000000         113240.000000
# mean          9.260164                   26.754539              0.592052
# std           5.022644                   13.637871              1.978707
# min           0.000000                    2.000000              0.000000
# 25%           6.000000                   17.000000              0.000000
# 50%           9.000000                   25.000000              0.000000
# 75%          12.000000                   35.000000              0.000000
# max          54.000000                  136.000000             83.000000
#
#        AmountDelinquent  DelinquenciesLast7Years  RevolvingCreditBalance  \
# count     106315.000000            112947.000000            1.063330e+05
# mean         984.507059                 4.154984            1.759871e+04
# std         7158.270157                10.160216            3.293640e+04
# min            0.000000                 0.000000            0.000000e+00
# 25%            0.000000                 0.000000            3.121000e+03
# 50%            0.000000                 0.000000            8.549000e+03
# 75%            0.000000                 3.000000            1.952100e+04
# max       463881.000000                99.000000            1.435667e+06
#
#        AvailableBankcardCredit  TradesNeverDelinquent (percentage)  \
# count            106393.000000                       106393.000000
# mean              11210.225447                            0.885897
# std               19818.361309                            0.148179
# min                   0.000000                            0.000000
# 25%                 880.000000                            0.820000
# 50%                4100.000000                            0.940000
# 75%               13180.000000                            1.000000
# max              646285.000000                            1.000000
#
#        DebtToIncomeRatio  StatedMonthlyIncome  ProsperPrincipalBorrowed  \
# count      105383.000000         1.139370e+05              22085.000000
# mean            0.275947         5.608026e+03               8472.311961
# std             0.551759         7.478497e+03               7395.507650
# min             0.000000         0.000000e+00                  0.000000
# 25%             0.140000         3.200333e+03               3500.000000
# 50%             0.220000         4.666667e+03               6000.000000
# 75%             0.320000         6.825000e+03              11000.000000
# max            10.010000         1.750003e+06              72499.000000
#
#        LoanOriginalAmount  MonthlyLoanPayment  LP_CustomerPayments  \
# count        113937.00000       113937.000000        113937.000000
# mean           8337.01385          272.475783          4183.079489
# std            6245.80058          192.697812          4790.907234
# min            1000.00000            0.000000            -2.349900
# 25%            4000.00000          131.620000          1005.760000
# 50%            6500.00000          217.740000          2583.830000
# 75%           12000.00000          371.580000          5548.400000
# max           35000.00000         2251.510000         40702.390000
#
#        LP_CustomerPrincipalPayments  LP_InterestandFees      Investors  \
# count                 113937.000000       113937.000000  113937.000000
# mean                    3105.536588         1077.542901      80.475228
# std                     4069.527670         1183.414168     103.239020
# min                        0.000000           -2.349900       1.000000
# 25%                      500.890000          274.870000       2.000000
# 50%                     1587.500000          700.840100      44.000000
# 75%                     4000.000000         1458.540000     115.000000
# max                    35000.000000        15617.030000    1189.000000
#
#        Credit_Score_Avg  Annual_Income
# count     113346.000000   1.139370e+05
# mean         695.067731   6.729631e+04
# std           66.458275   8.974197e+04
# min            9.500000   0.000000e+00
# 25%          669.500000   3.840400e+04
# 50%          689.500000   5.600000e+04
# 75%          729.500000   8.190000e+04
# max          889.500000   2.100004e+07

# %%
df.sample(5)
# Out:
#        Term LoanStatus  BorrowerAPR  BorrowerRate  LenderYield BorrowerState  \
# 45010    36  Defaulted      0.21639        0.2090       0.1990            OH
# 76971    36    Current      0.31032        0.2712       0.2612            ID
# 79725    60    Current      0.12992        0.1076       0.0976            MN
# 37231    60    Current      0.17685        0.1535       0.1435            AK
# 28564    60    Current      0.13227        0.1099       0.0999            PA
#
#                     Occupation  IsBorrowerHomeowner  CreditScoreRangeLower  \
# 45010  Food Service Management                False                  680.0
# 76971                    Other                 True                  600.0
# 79725                    Other                False                  780.0
# 37231                    Other                 True                  700.0
# 28564                  Teacher                False                  800.0
#
#        CreditScoreRangeUpper  CurrentCreditLines  OpenCreditLines  \
# 45010                  699.0                10.0             10.0
# 76971                  619.0                11.0             11.0
# 79725                  799.0                 4.0              4.0
# 37231                  719.0                 6.0              6.0
# 28564                  819.0                 5.0              5.0
#
#        TotalCreditLinespast7years  CurrentDelinquencies  AmountDelinquent  \
# 45010                        22.0                   0.0               0.0
# 76971                        25.0                   0.0               0.0
# 79725                        52.0                   0.0               0.0
# 37231                        13.0                   0.0               0.0
# 28564                        13.0                   0.0               0.0
#
#        DelinquenciesLast7Years  RevolvingCreditBalance  \
# 45010                      0.0                 26512.0
# 76971                      0.0                  3431.0
# 79725                      2.0                  2654.0
# 37231                      0.0                 44780.0
# 28564                      0.0                  3360.0
#
#        AvailableBankcardCredit  TradesNeverDelinquent (percentage)  \
# 45010                  41354.0                                0.95
# 76971                      0.0                                0.70
# 79725                  14301.0                                0.95
# 37231                    720.0                                1.00
# 28564                  21440.0                                0.91
#
#        DebtToIncomeRatio     IncomeRange  StatedMonthlyIncome  \
# 45010              10.01       $1-24,999             0.083333
# 76971               0.41  $50,000-74,999          5416.666667
# 79725                NaN    Not employed             0.000000
# 37231               0.26  $50,000-74,999          5583.333333
# 28564               0.18  $50,000-74,999          5416.666667
#
#        ProsperPrincipalBorrowed  LoanOriginalAmount  MonthlyLoanPayment  \
# 45010                       NaN               20000              752.47
# 76971                    8500.0                3500              143.11
# 79725                       NaN                8000              172.98
# 37231                       NaN               20000              479.48
# 28564                       NaN               20000              434.75
#
#        LP_CustomerPayments  LP_CustomerPrincipalPayments  LP_InterestandFees  \
# 45010            2267.4100                       1449.38            818.0300
# 76971            1287.9900                        625.18            662.8100
# 79725            2421.7200                       1500.93            920.7900
# 37231             950.5490                        440.33            510.2190
# 28564            2602.4781                       1535.66           1066.8181
#
#        Investors  Credit_Score_Avg  Annual_Income
# 45010        330             689.5            1.0
# 76971         40             609.5        65000.0
# 79725        111             789.5            0.0
# 37231          1             709.5        67000.0
# 28564          1             809.5        65000.0

# %% [markdown]
# ## Current Credit Lines
#
# The number of current lines of credit that the borrowers have.  The list continues to 59, but was cut off at 40.
# In the logarithmic plot, the most common number of values present is 10, which is a lot. Personally, I have 2, so 10 is a huge amount to me.

# %%
binsize = 1
bins = np.arange(0, 50 + binsize, binsize)
plt.hist(data = df, x = 'CurrentCreditLines', bins = bins);
plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50], [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50])
plt.xlabel('Number of Lines of Credit');
plt.title('Current Credit Lines');

# %%
logbinsize = 0.05
logbins = 10** np.arange(0.1, 1.7 + logbinsize, logbinsize)

plt.hist(data = df, x = 'CurrentCreditLines', bins = logbins);
plt.xscale('log');
plt.xticks([1, 3, 7, 10, 20, 30, 50],[1, 3, 7, 10, 20, 30, 50]);
plt.xlabel("Number of Lines of Credit");
plt.title("Number of Lines of Credit");

# %% [markdown]
# ## Current Delinquencies
#
# With the vast number (89742) of delinquencies being 0, a log plot is not very practical for a histogram; either in log or linear format.

# %%
df.CurrentDelinquencies.value_counts()
# Out:
# 0.0     89742
# 1.0     11716
# 2.0      4357
# 3.0      2098
# 4.0      1379
# 5.0       916
# 6.0       690
# 7.0       517
# 8.0       397
# 9.0       289
# 10.0      212
# 11.0      191
# 12.0      147
# 13.0      111
# 15.0       83
# 14.0       71
# 16.0       58
# 17.0       40
# 18.0       37
# 21.0       31
# 19.0       28
# 20.0       27
# 22.0       21
# 27.0       12
# 24.0       12
# 23.0        9
# 26.0        8
# 31.0        6
# 25.0        5
# 28.0        5
# 32.0        5
# 30.0        2
# 36.0        2
# 35.0        2
# 41.0        2
# 40.0        1
# 39.0        1
# 82.0        1
# 64.0        1
# 33.0        1
# 50.0        1
# 57.0        1
# 83.0        1
# 51.0        1
# 45.0        1
# 59.0        1
# 37.0        1
# Name: CurrentDelinquencies, dtype: int64

# %%
binsize = 1
bins = np.arange(0, 30 + binsize, binsize)
plt.hist(data = df, x = 'CurrentDelinquencies', bins = bins);
plt.xticks([0, 5, 10, 15, 20, 25, 30], [0, 5, 10, 15, 20, 25, 30])
plt.xlabel('Current Delinquencies');
plt.title('Current Delinquencies');

# %%
logbinsize = 0.05
logbins = 10** np.arange(0.1, 1.7 + logbinsize, logbinsize)

plt.hist(data = df, x = 'CurrentDelinquencies', bins = logbins);
plt.xscale('log');
plt.xticks([1, 3, 7, 10, 20, 30, 50],[1, 3, 7, 10, 20, 30, 50]);
plt.xlabel("Number of Lines of Credit");
plt.title("Number of Lines of Credit");

# %% [markdown]
# ## Available Bankcard Credit
#
# Max credit card limit

# %%
binsize = 500
bins = np.arange(0, 1.25e5 + binsize, binsize)
plt.hist(data = df, x = 'AvailableBankcardCredit', bins = bins);
#plt.xticks([0, 5, 10, 15, 20, 25, 30], [0, 5, 10, 15, 20, 25, 30])
plt.xlabel('Available Bankcard Credit');
plt.ylim(0, 12000);
plt.title('Available Bankcard Credit');

# %%
logbinsize = 0.1
logbins = 10** np.arange(1, 4 + logbinsize, logbinsize)

plt.hist(data = df, x = 'AvailableBankcardCredit', bins = logbins);
plt.xscale('log');
#plt.xticks([1, 3, 7, 10, 20, 30, 50],[1, 3, 7, 10, 20, 30, 50]);
plt.xlabel("Number of Lines of Credit");
plt.title("Number of Lines of Credit");

# %%
def sample_10000(dataframe):
    return dataframe.sample(10000)

# %% [markdown]
# ## Multivariable Exploration
# Exploration will start with comparing varibles to the principal borrowed
#
# Because there are 113,000 loans, each of the plots will sample 10,000 loans to avoid clutter
# > The only difference between the two very similar plots is that there are a lot of small (less than $5000) loans made to people with a smaller income who do not own a home

# %%
df_sample = df.sample(10000)

# %%
df_sample = df.sample(10000)
g = sb.FacetGrid(data = df_sample, col = 'IsBorrowerHomeowner', palette = 'viridis_r', height = 5, aspect = 1.5);
g.map(plt.scatter, 'LoanOriginalAmount', 'StatedMonthlyIncome', alpha = 0.2);
g.add_legend();
plt.yscale('log');
plt.yticks([10, 100, 1000, 10000, 1e5, 1e6], [10, 100, 1000, '10K', '100K']);
plt.ylim(1, 600000);
plt.ylabel('Stated Monthly Income ($)');
plt.xlabel('Original Loan Amount ($)')
plt.show()

# %% [markdown]
# ## Multivariate Plot Matrices
#
# In order to compare multiple variables and find the important variables sooner, plot matrices will be used to show multiple variables' comparisons.

# %%
first_six = ['BorrowerAPR', 'LenderYield', 'Credit_Score_Avg', 'RevolvingCreditBalance', 'AvailableBankcardCredit', 'LoanOriginalAmount']
g = sb.PairGrid(data = df_sample, vars = first_six);
#g.map(plt.scatter);

g.map_offdiag(plt.scatter);
#del bins
#g.map_diag(plt.hist);

# %%
sb.heatmap(df_sample[first_six].corr(), cmap = 'rocket_r', annot = True, fmt = '0.2f', vmin = 0);

# %%
pd.plotting.scatter_matrix(df_sample[first_six], figsize = (15, 15));

# %% [markdown]
# ## Second plot utilizing matrix plots

# %%
second_six = ['CurrentCreditLines', 'OpenCreditLines', 'TotalCreditLinespast7years', 'CurrentDelinquencies', 'DebtToIncomeRatio', 'LoanOriginalAmount']

g = sb.PairGrid(data = df_sample, vars = second_six);
g.map_offdiag(plt.scatter);
#g.map_diag(plt.hist);

# %%
sb.heatmap(df_sample[second_six].corr(), cmap = 'rocket_r', annot = True, fmt = '0.2f', vmin = 0);

# %%
loan_stats
# Out:
#                 Term    BorrowerAPR   BorrowerRate    LenderYield  \
# count  113937.000000  113912.000000  113937.000000  113937.000000
# mean       40.830248       0.218828       0.192764       0.182701
# std        10.436212       0.080364       0.074818       0.074516
# min        12.000000       0.006530       0.000000      -0.010000
# 25%        36.000000       0.156290       0.134000       0.124200
# 50%        36.000000       0.209760       0.184000       0.173000
# 75%        36.000000       0.283810       0.250000       0.240000
# max        60.000000       0.512290       0.497500       0.492500
#
#        CreditScoreRangeLower  CreditScoreRangeUpper  CurrentCreditLines  \
# count          113346.000000          113346.000000       106333.000000
# mean              685.567731             704.567731           10.317192
# std                66.458275              66.458275            5.457866
# min                 0.000000              19.000000            0.000000
# 25%               660.000000             679.000000            7.000000
# 50%               680.000000             699.000000           10.000000
# 75%               720.000000             739.000000           13.000000
# max               880.000000             899.000000           59.000000
#
#        OpenCreditLines  TotalCreditLinespast7years  CurrentDelinquencies  \
# count    106333.000000               113240.000000         113240.000000
# mean          9.260164                   26.754539              0.592052
# std           5.022644                   13.637871              1.978707
# min           0.000000                    2.000000              0.000000
# 25%           6.000000                   17.000000              0.000000
# 50%           9.000000                   25.000000              0.000000
# 75%          12.000000                   35.000000              0.000000
# max          54.000000                  136.000000             83.000000
#
#        AmountDelinquent  DelinquenciesLast7Years  RevolvingCreditBalance  \
# count     106315.000000            112947.000000            1.063330e+05
# mean         984.507059                 4.154984            1.759871e+04
# std         7158.270157                10.160216            3.293640e+04
# min            0.000000                 0.000000            0.000000e+00
# 25%            0.000000                 0.000000            3.121000e+03
# 50%            0.000000                 0.000000            8.549000e+03
# 75%            0.000000                 3.000000            1.952100e+04
# max       463881.000000                99.000000            1.435667e+06
#
#        AvailableBankcardCredit  TradesNeverDelinquent (percentage)  \
# count            106393.000000                       106393.000000
# mean              11210.225447                            0.885897
# std               19818.361309                            0.148179
# min                   0.000000                            0.000000
# 25%                 880.000000                            0.820000
# 50%                4100.000000                            0.940000
# 75%               13180.000000                            1.000000
# max              646285.000000                            1.000000
#
#        DebtToIncomeRatio  StatedMonthlyIncome  ProsperPrincipalBorrowed  \
# count      105383.000000         1.139370e+05              22085.000000
# mean            0.275947         5.608026e+03               8472.311961
# std             0.551759         7.478497e+03               7395.507650
# min             0.000000         0.000000e+00                  0.000000
# 25%             0.140000         3.200333e+03               3500.000000
# 50%             0.220000         4.666667e+03               6000.000000
# 75%             0.320000         6.825000e+03              11000.000000
# max            10.010000         1.750003e+06              72499.000000
#
#        LoanOriginalAmount  MonthlyLoanPayment  LP_CustomerPayments  \
# count        113937.00000       113937.000000        113937.000000
# mean           8337.01385          272.475783          4183.079489
# std            6245.80058          192.697812          4790.907234
# min            1000.00000            0.000000            -2.349900
# 25%            4000.00000          131.620000          1005.760000
# 50%            6500.00000          217.740000          2583.830000
# 75%           12000.00000          371.580000          5548.400000
# max           35000.00000         2251.510000         40702.390000
#
#        LP_CustomerPrincipalPayments  LP_InterestandFees      Investors  \
# count                 113937.000000       113937.000000  113937.000000
# mean                    3105.536588         1077.542901      80.475228
# std                     4069.527670         1183.414168     103.239020
# min                        0.000000           -2.349900       1.000000
# 25%                      500.890000          274.870000       2.000000
# 50%                     1587.500000          700.840100      44.000000
# 75%                     4000.000000         1458.540000     115.000000
# max                    35000.000000        15617.030000    1189.000000
#
#        Credit_Score_Avg  Annual_Income
# count     113346.000000   1.139370e+05
# mean         695.067731   6.729631e+04
# std           66.458275   8.974197e+04
# min            9.500000   0.000000e+00
# 25%          669.500000   3.840400e+04
# 50%          689.500000   5.600000e+04
# 75%          729.500000   8.190000e+04
# max          889.500000   2.100004e+07

# %%
df.sample(5)
# Out:
#         Term              LoanStatus  BorrowerAPR  BorrowerRate  LenderYield  \
# 12347     36               Completed      0.24507        0.2300       0.2100
# 25035     36  Past Due (91-120 days)      0.35797        0.3177       0.3077
# 93983     36    Past Due (1-15 days)      0.18479        0.1485       0.1385
# 13855     36                 Current      0.13799        0.1099       0.0999
# 103546    36                 Current      0.22773        0.1905       0.1805
#
#        BorrowerState                Occupation  IsBorrowerHomeowner  \
# 12347             CA                     Other                False
# 25035             FL  Administrative Assistant                 True
# 93983             NY                       NaN                False
# 13855             NY              Professional                False
# 103546            PA                   Analyst                False
#
#         CreditScoreRangeLower  CreditScoreRangeUpper  CurrentCreditLines  \
# 12347                   520.0                  539.0                 5.0
# 25035                   660.0                  679.0                11.0
# 93983                   720.0                  739.0                11.0
# 13855                   740.0                  759.0                 5.0
# 103546                  700.0                  719.0                 7.0
#
#         OpenCreditLines  TotalCreditLinespast7years  CurrentDelinquencies  \
# 12347               4.0                         8.0                   0.0
# 25035              11.0                        19.0                   1.0
# 93983              11.0                        17.0                   0.0
# 13855               5.0                         6.0                   0.0
# 103546              6.0                        21.0                   0.0
#
#         AmountDelinquent  DelinquenciesLast7Years  RevolvingCreditBalance  \
# 12347                0.0                      2.0                  1405.0
# 25035               33.0                      0.0                 10648.0
# 93983                0.0                      0.0                  8622.0
# 13855                0.0                      0.0                 16588.0
# 103546               0.0                      0.0                 12839.0
#
#         AvailableBankcardCredit  TradesNeverDelinquent (percentage)  \
# 12347                     245.0                                0.42
# 25035                    3170.0                                0.87
# 93983                    2136.0                                1.00
# 13855                   23412.0                                1.00
# 103546                   2911.0                                1.00
#
#         DebtToIncomeRatio     IncomeRange  StatedMonthlyIncome  \
# 12347                0.09       $1-24,999          1833.333333
# 25035                0.31  $50,000-74,999          4333.333333
# 93983                0.44  $25,000-49,999          3166.666667
# 13855                0.08       $100,000+         12500.000000
# 103546               0.17  $75,000-99,999          6416.666667
#
#         ProsperPrincipalBorrowed  LoanOriginalAmount  MonthlyLoanPayment  \
# 12347                        NaN                2800              108.39
# 25035                        NaN                4000              173.71
# 93983                        NaN               10000              345.92
# 13855                        NaN               25000              818.35
# 103546                       NaN               22000              806.99
#
#         LP_CustomerPayments  LP_CustomerPrincipalPayments  LP_InterestandFees  \
# 12347             3861.1000                       2800.04           1061.0600
# 25035             3111.7800                       1473.11           1638.6700
# 93983             1383.6800                        900.05            483.6300
# 13855             3265.8726                       2380.45            885.4226
# 103546            7200.0000                       7073.70            126.3000
#
#         Investors  Credit_Score_Avg  Annual_Income
# 12347          85             529.5        22000.0
# 25035           9             669.5        52000.0
# 93983         176             729.5        38000.0
# 13855           1             749.5       150000.0
# 103546          1             709.5        77000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 31 columns):
# Term                                  113937 non-null int64
# LoanStatus                            113937 non-null object
# BorrowerAPR                           113912 non-null float64
# BorrowerRate                          113937 non-null float64
# LenderYield                           113937 non-null float64
# BorrowerState                         108422 non-null object
# Occupation                            110349 non-null object
# IsBorrowerHomeowner                   113937 non-null bool
# CreditScoreRangeLower                 113346 non-null float64
# CreditScoreRangeUpper                 113346 non-null float64
# CurrentCreditLines                    106333 non-null float64
# OpenCreditLines                       106333 non-null float64
# TotalCreditLinespast7years            113240 non-null float64
# CurrentDelinquencies                  113240 non-null float64
# AmountDelinquent                      106315 non-null float64
# DelinquenciesLast7Years               112947 non-null float64
# RevolvingCreditBalance                106333 non-null float64
# AvailableBankcardCredit               106393 non-null float64
# TradesNeverDelinquent (percentage)    106393 non-null float64
# DebtToIncomeRatio                     105383 non-null float64
# IncomeRange                           113937 non-null object
# StatedMonthlyIncome                   113937 non-null float64
# ProsperPrincipalBorrowed              22085 non-null float64
# LoanOriginalAmount                    113937 non-null int64
# MonthlyLoanPayment                    113937 non-null float64
# LP_CustomerPayments                   113937 non-null float64
# LP_CustomerPrincipalPayments          113937 non-null float64
# LP_InterestandFees                    113937 non-null float64
# Investors                             113937 non-null int64
# Credit_Score_Avg                      113346 non-null float64
# Annual_Income                         113937 non-null float64
# dtypes: bool(1), float64(23), int64(3), object(4)
# memory usage: 26.2+ MB

# %%
first_six = ['BorrowerAPR', 'LenderYield', 'Credit_Score_Avg', 'RevolvingCreditBalance', 'AvailableBankcardCredit', 'LoanOriginalAmount']
second_six = ['CurrentCreditLines', 'OpenCreditLines', 'TotalCreditLinespast7years', 'CurrentDelinquencies', 'DebtToIncomeRatio', 'LoanOriginalAmount']
third_set = ['MonthlyLoanPayment', 'LP_CustomerPayments', 'LP_CustomerPrincipalPayments', 'LP_InterestandFees', 'Investors', 'LoanOriginalAmount']

# %%
g = sb.PairGrid(data = df_sample, vars = third_set);
g.map_offdiag(plt.scatter);
g.map_diag(plt.hist);

# %%
sb.heatmap(df_sample[third_set].corr(), cmap = 'rocket_r', annot = True, fmt = '0.2f', vmin = 0);

# %% [markdown]
# # Heatmap for all Columns
#
# Instead of creating heatmaps six at a time, create maps for all the variables in the dataset

# %%
plt.subplots(figsize = (15, 15));
sb.heatmap(df[Interesting_columns].corr(), cmap = 'RdBu_r', center = 0, annot = True, fmt = '0.2f');
#fig.suptitle('Loan Attributes Correlation Heatmap', fontsize=10, fontweight='bold');

#cmap = sb.diverging_palette(220, 10, as_cmap=True)
#sb.heatmap(df1.iloc[:, 1:6:], annot=True, linewidths=.5, ax=ax)

# %% [markdown]
# # Correlations between values greater than |0.3|
#
# > A list of the values with high correlation values that are not related (e.g. Upper and Lower Credit Score Range)
#
# The list was turned into a dataframe which was sorted to remove all duplicates and rows where the valuables would be related

# %%
test_corr = df[Interesting_columns].corr()
test_corr.round(3)
#test_corr = test_corr.to_dict('index')
test_corr
# Out:
#                                         Term  BorrowerAPR  BorrowerRate  \
# Term                                1.000000    -0.011183      0.020085
# BorrowerAPR                        -0.011183     1.000000      0.989824
# BorrowerRate                        0.020085     0.989824      1.000000
# LenderYield                         0.020556     0.989329      0.999211
# IsBorrowerHomeowner                 0.085339    -0.132823     -0.134431
# CreditScoreRangeLower               0.126263    -0.429707     -0.461567
# CreditScoreRangeUpper               0.126263    -0.429707     -0.461567
# CurrentCreditLines                  0.077072    -0.093481     -0.097473
# OpenCreditLines                     0.096309    -0.098860     -0.105998
# TotalCreditLinespast7years          0.076528     0.002513     -0.005793
# CurrentDelinquencies               -0.083807     0.149404      0.176530
# AmountDelinquent                   -0.016459     0.065679      0.065645
# DelinquenciesLast7Years            -0.041492     0.162225      0.170279
# RevolvingCreditBalance              0.026022    -0.058539     -0.059608
# AvailableBankcardCredit             0.015348    -0.348926     -0.343861
# TradesNeverDelinquent (percentage)  0.119342    -0.241349     -0.261189
# DebtToIncomeRatio                  -0.014670     0.056327      0.062917
# StatedMonthlyIncome                 0.028479    -0.082338     -0.088982
# ProsperPrincipalBorrowed            0.130493    -0.206209     -0.206461
# LoanOriginalAmount                  0.338927    -0.322887     -0.328960
# MonthlyLoanPayment                  0.091026    -0.226653     -0.244742
# LP_CustomerPayments                -0.069696    -0.111350     -0.081055
# LP_CustomerPrincipalPayments       -0.128255    -0.180445     -0.153722
# LP_InterestandFees                  0.158890     0.169726      0.200479
# Investors                          -0.045137    -0.307606     -0.274217
# Credit_Score_Avg                    0.126263    -0.429707     -0.461567
# Annual_Income                       0.028479    -0.082338     -0.088982
#
#                                     LenderYield  IsBorrowerHomeowner  \
# Term                                   0.020556             0.085339
# BorrowerAPR                            0.989329            -0.132823
# BorrowerRate                           0.999211            -0.134431
# LenderYield                            1.000000            -0.132993
# IsBorrowerHomeowner                   -0.132993             1.000000
# CreditScoreRangeLower                 -0.454350             0.293516
# CreditScoreRangeUpper                 -0.454350             0.293516
# CurrentCreditLines                    -0.096318             0.278295
# OpenCreditLines                       -0.104790             0.279033
# TotalCreditLinespast7years            -0.005470             0.293587
# CurrentDelinquencies                   0.171854            -0.055454
# AmountDelinquent                       0.065021             0.038122
# DelinquenciesLast7Years                0.168000            -0.070798
# RevolvingCreditBalance                -0.058665             0.224649
# AvailableBankcardCredit               -0.340939             0.142039
# TradesNeverDelinquent (percentage)    -0.256283             0.137122
# DebtToIncomeRatio                      0.061942             0.000177
# StatedMonthlyIncome                   -0.088208             0.140051
# ProsperPrincipalBorrowed              -0.206725             0.148501
# LoanOriginalAmount                    -0.328455             0.206787
# MonthlyLoanPayment                    -0.244214             0.179703
# LP_CustomerPayments                   -0.079052             0.094572
# LP_CustomerPrincipalPayments          -0.151563             0.089186
# LP_InterestandFees                     0.201162             0.076168
# Investors                             -0.274174             0.125093
# Credit_Score_Avg                      -0.454350             0.293516
# Annual_Income                         -0.088208             0.140051
#
#                                     CreditScoreRangeLower  \
# Term                                             0.126263
# BorrowerAPR                                     -0.429707
# BorrowerRate                                    -0.461567
# LenderYield                                     -0.454350
# IsBorrowerHomeowner                              0.293516
# CreditScoreRangeLower                            1.000000
# CreditScoreRangeUpper                            1.000000
# CurrentCreditLines                               0.142092
# OpenCreditLines                                  0.148210
# TotalCreditLinespast7years                       0.108707
# CurrentDelinquencies                            -0.368450
# AmountDelinquent                                -0.065849
# DelinquenciesLast7Years                         -0.251219
# RevolvingCreditBalance                           0.088848
# AvailableBankcardCredit                          0.453257
# TradesNeverDelinquent (percentage)               0.468899
# DebtToIncomeRatio                               -0.013169
# StatedMonthlyIncome                              0.107901
# ProsperPrincipalBorrowed                         0.231863
# LoanOriginalAmount                               0.340874
# MonthlyLoanPayment                               0.292532
# LP_CustomerPayments                              0.210125
# LP_CustomerPrincipalPayments                     0.225058
# LP_InterestandFees                               0.076810
# Investors                                        0.271350
# Credit_Score_Avg                                 1.000000
# Annual_Income                                    0.107901
#
#                                     CreditScoreRangeUpper  CurrentCreditLines  \
# Term                                             0.126263            0.077072
# BorrowerAPR                                     -0.429707           -0.093481
# BorrowerRate                                    -0.461567           -0.097473
# LenderYield                                     -0.454350           -0.096318
# IsBorrowerHomeowner                              0.293516            0.278295
# CreditScoreRangeLower                            1.000000            0.142092
# CreditScoreRangeUpper                            1.000000            0.142092
# CurrentCreditLines                               0.142092            1.000000
# OpenCreditLines                                  0.148210            0.960409
# TotalCreditLinespast7years                       0.108707            0.627594
# CurrentDelinquencies                            -0.368450           -0.165860
# AmountDelinquent                                -0.065849           -0.072590
# DelinquenciesLast7Years                         -0.251219           -0.180398
# RevolvingCreditBalance                           0.088848            0.333656
# AvailableBankcardCredit                          0.453257            0.318165
# TradesNeverDelinquent (percentage)               0.468899            0.338103
# DebtToIncomeRatio                               -0.013169            0.091878
# StatedMonthlyIncome                              0.107901            0.143329
# ProsperPrincipalBorrowed                         0.231863            0.142210
# LoanOriginalAmount                               0.340874            0.201383
# MonthlyLoanPayment                               0.292532            0.186922
# LP_CustomerPayments                              0.210125            0.022195
# LP_CustomerPrincipalPayments                     0.225058            0.018597
# LP_InterestandFees                               0.076810            0.025585
# Investors                                        0.271350            0.039449
# Credit_Score_Avg                                 1.000000            0.142092
# Annual_Income                                    0.107901            0.143329
#
#                                     OpenCreditLines  \
# Term                                       0.096309
# BorrowerAPR                               -0.098860
# BorrowerRate                              -0.105998
# LenderYield                               -0.104790
# IsBorrowerHomeowner                        0.279033
# CreditScoreRangeLower                      0.148210
# CreditScoreRangeUpper                      0.148210
# CurrentCreditLines                         0.960409
# OpenCreditLines                            1.000000
# TotalCreditLinespast7years                 0.586731
# CurrentDelinquencies                      -0.161929
# AmountDelinquent                          -0.070437
# DelinquenciesLast7Years                   -0.181438
# RevolvingCreditBalance                     0.342742
# AvailableBankcardCredit                    0.331721
# TradesNeverDelinquent (percentage)         0.349783
# DebtToIncomeRatio                          0.090212
# StatedMonthlyIncome                        0.143035
# ProsperPrincipalBorrowed                   0.154561
# LoanOriginalAmount                         0.223681
# MonthlyLoanPayment                         0.205010
# LP_CustomerPayments                        0.003471
# LP_CustomerPrincipalPayments              -0.000480
# LP_InterestandFees                         0.015574
# Investors                                  0.025211
# Credit_Score_Avg                           0.148210
# Annual_Income                              0.143035
#
#                                     TotalCreditLinespast7years  \
# Term                                                  0.076528
# BorrowerAPR                                           0.002513
# BorrowerRate                                         -0.005793
# LenderYield                                          -0.005470
# IsBorrowerHomeowner                                   0.293587
# CreditScoreRangeLower                                 0.108707
# CreditScoreRangeUpper                                 0.108707
# CurrentCreditLines                                    0.627594
# OpenCreditLines                                       0.586731
# TotalCreditLinespast7years                            1.000000
# CurrentDelinquencies                                  0.067601
# AmountDelinquent                                      0.050984
# DelinquenciesLast7Years                               0.146574
# RevolvingCreditBalance                                0.237530
# AvailableBankcardCredit                               0.194360
# TradesNeverDelinquent (percentage)                    0.044294
# DebtToIncomeRatio                                     0.037486
# StatedMonthlyIncome                                   0.149552
# ProsperPrincipalBorrowed                              0.115169
# LoanOriginalAmount                                    0.145012
# MonthlyLoanPayment                                    0.134829
# LP_CustomerPayments                                   0.017492
# LP_CustomerPrincipalPayments                          0.010455
# LP_InterestandFees                                    0.034835
# Investors                                             0.008226
# Credit_Score_Avg                                      0.108707
# Annual_Income                                         0.149552
#
#                                     CurrentDelinquencies  AmountDelinquent  \
# Term                                           -0.083807         -0.016459
# BorrowerAPR                                     0.149404          0.065679
# BorrowerRate                                    0.176530          0.065645
# LenderYield                                     0.171854          0.065021
# IsBorrowerHomeowner                            -0.055454          0.038122
# CreditScoreRangeLower                          -0.368450         -0.065849
# CreditScoreRangeUpper                          -0.368450         -0.065849
# CurrentCreditLines                             -0.165860         -0.072590
# OpenCreditLines                                -0.161929         -0.070437
# TotalCreditLinespast7years                      0.067601          0.050984
# CurrentDelinquencies                            1.000000          0.340549
# AmountDelinquent                                0.340549          1.000000
# DelinquenciesLast7Years                         0.377777          0.233270
# RevolvingCreditBalance                         -0.088831         -0.021869
# AvailableBankcardCredit                        -0.092433         -0.020286
# TradesNeverDelinquent (percentage)             -0.458761         -0.138625
# DebtToIncomeRatio                              -0.024265         -0.019397
# StatedMonthlyIncome                            -0.038835          0.008662
# ProsperPrincipalBorrowed                       -0.088950          0.006080
# LoanOriginalAmount                             -0.172139         -0.038756
# MonthlyLoanPayment                             -0.158558         -0.029638
# LP_CustomerPayments                            -0.076932         -0.015314
# LP_CustomerPrincipalPayments                   -0.078224         -0.018724
# LP_InterestandFees                             -0.042454          0.002477
# Investors                                      -0.087091         -0.027039
# Credit_Score_Avg                               -0.368450         -0.065849
# Annual_Income                                  -0.038835          0.008662
#
#                                     DelinquenciesLast7Years  \
# Term                                              -0.041492
# BorrowerAPR                                        0.162225
# BorrowerRate                                       0.170279
# LenderYield                                        0.168000
# IsBorrowerHomeowner                               -0.070798
# CreditScoreRangeLower                             -0.251219
# CreditScoreRangeUpper                             -0.251219
# CurrentCreditLines                                -0.180398
# OpenCreditLines                                   -0.181438
# TotalCreditLinespast7years                         0.146574
# CurrentDelinquencies                               0.377777
# AmountDelinquent                                   0.233270
# DelinquenciesLast7Years                            1.000000
# RevolvingCreditBalance                            -0.125917
# AvailableBankcardCredit                           -0.134486
# TradesNeverDelinquent (percentage)                -0.516443
# DebtToIncomeRatio                                 -0.043877
# StatedMonthlyIncome                               -0.025805
# ProsperPrincipalBorrowed                          -0.097849
# LoanOriginalAmount                                -0.136667
# MonthlyLoanPayment                                -0.121247
# LP_CustomerPayments                               -0.076597
# LP_CustomerPrincipalPayments                      -0.082582
# LP_InterestandFees                                -0.026103
# Investors                                         -0.105479
# Credit_Score_Avg                                  -0.251219
# Annual_Income                                     -0.025805
#
#                                     RevolvingCreditBalance  \
# Term                                              0.026022
# BorrowerAPR                                      -0.058539
# BorrowerRate                                     -0.059608
# LenderYield                                      -0.058665
# IsBorrowerHomeowner                               0.224649
# CreditScoreRangeLower                             0.088848
# CreditScoreRangeUpper                             0.088848
# CurrentCreditLines                                0.333656
# OpenCreditLines                                   0.342742
# TotalCreditLinespast7years                        0.237530
# CurrentDelinquencies                             -0.088831
# AmountDelinquent                                 -0.021869
# DelinquenciesLast7Years                          -0.125917
# RevolvingCreditBalance                            1.000000
# AvailableBankcardCredit                           0.239789
# TradesNeverDelinquent (percentage)                0.211566
# DebtToIncomeRatio                                 0.038636
# StatedMonthlyIncome                               0.194898
# ProsperPrincipalBorrowed                          0.149789
# LoanOriginalAmount                                0.190879
# MonthlyLoanPayment                                0.193021
# LP_CustomerPayments                               0.079952
# LP_CustomerPrincipalPayments                      0.070804
# LP_InterestandFees                                0.079139
# Investors                                         0.072185
# Credit_Score_Avg                                  0.088848
# Annual_Income                                     0.194898
#
#                                     AvailableBankcardCredit  \
# Term                                               0.015348
# BorrowerAPR                                       -0.348926
# BorrowerRate                                      -0.343861
# LenderYield                                       -0.340939
# IsBorrowerHomeowner                                0.142039
# CreditScoreRangeLower                              0.453257
# CreditScoreRangeUpper                              0.453257
# CurrentCreditLines                                 0.318165
# OpenCreditLines                                    0.331721
# TotalCreditLinespast7years                         0.194360
# CurrentDelinquencies                              -0.092433
# AmountDelinquent                                  -0.020286
# DelinquenciesLast7Years                           -0.134486
# RevolvingCreditBalance                             0.239789
# AvailableBankcardCredit                            1.000000
# TradesNeverDelinquent (percentage)                 0.238430
# DebtToIncomeRatio                                  0.002059
# StatedMonthlyIncome                                0.111869
# ProsperPrincipalBorrowed                           0.158976
# LoanOriginalAmount                                 0.229866
# MonthlyLoanPayment                                 0.196238
# LP_CustomerPayments                                0.127857
# LP_CustomerPrincipalPayments                       0.152325
# LP_InterestandFees                                -0.007003
# Investors                                          0.207695
# Credit_Score_Avg                                   0.453257
# Annual_Income                                      0.111869
#
#                                     TradesNeverDelinquent (percentage)  \
# Term                                                          0.119342
# BorrowerAPR                                                  -0.241349
# BorrowerRate                                                 -0.261189
# LenderYield                                                  -0.256283
# IsBorrowerHomeowner                                           0.137122
# CreditScoreRangeLower                                         0.468899
# CreditScoreRangeUpper                                         0.468899
# CurrentCreditLines                                            0.338103
# OpenCreditLines                                               0.349783
# TotalCreditLinespast7years                                    0.044294
# CurrentDelinquencies                                         -0.458761
# AmountDelinquent                                             -0.138625
# DelinquenciesLast7Years                                      -0.516443
# RevolvingCreditBalance                                        0.211566
# AvailableBankcardCredit                                       0.238430
# TradesNeverDelinquent (percentage)                            1.000000
# DebtToIncomeRatio                                             0.054639
# StatedMonthlyIncome                                           0.061633
# ProsperPrincipalBorrowed                                      0.197618
# LoanOriginalAmount                                            0.252534
# MonthlyLoanPayment                                            0.220534
# LP_CustomerPayments                                           0.055043
# LP_CustomerPrincipalPayments                                  0.067109
# LP_InterestandFees                                           -0.008248
# Investors                                                     0.099087
# Credit_Score_Avg                                              0.468899
# Annual_Income                                                 0.061633
#
#                                     DebtToIncomeRatio  StatedMonthlyIncome  \
# Term                                        -0.014670             0.028479
# BorrowerAPR                                  0.056327            -0.082338
# BorrowerRate                                 0.062917            -0.088982
# LenderYield                                  0.061942            -0.088208
# IsBorrowerHomeowner                          0.000177             0.140051
# CreditScoreRangeLower                       -0.013169             0.107901
# CreditScoreRangeUpper                       -0.013169             0.107901
# CurrentCreditLines                           0.091878             0.143329
# OpenCreditLines                              0.090212             0.143035
# TotalCreditLinespast7years                   0.037486             0.149552
# CurrentDelinquencies                        -0.024265            -0.038835
# AmountDelinquent                            -0.019397             0.008662
# DelinquenciesLast7Years                     -0.043877            -0.025805
# RevolvingCreditBalance                       0.038636             0.194898
# AvailableBankcardCredit                      0.002059             0.111869
# TradesNeverDelinquent (percentage)           0.054639             0.061633
# DebtToIncomeRatio                            1.000000            -0.122659
# StatedMonthlyIncome                         -0.122659             1.000000
# ProsperPrincipalBorrowed                     0.007388             0.267711
# LoanOriginalAmount                           0.010112             0.201259
# MonthlyLoanPayment                           0.027598             0.196830
# LP_CustomerPayments                          0.021246             0.085729
# LP_CustomerPrincipalPayments                 0.011279             0.082557
# LP_InterestandFees                           0.047804             0.063166
# Investors                                    0.004095             0.076244
# Credit_Score_Avg                            -0.013169             0.107901
# Annual_Income                               -0.122659             1.000000
#
#                                     ProsperPrincipalBorrowed  \
# Term                                                0.130493
# BorrowerAPR                                        -0.206209
# BorrowerRate                                       -0.206461
# LenderYield                                        -0.206725
# IsBorrowerHomeowner                                 0.148501
# CreditScoreRangeLower                               0.231863
# CreditScoreRangeUpper                               0.231863
# CurrentCreditLines                                  0.142210
# OpenCreditLines                                     0.154561
# TotalCreditLinespast7years                          0.115169
# CurrentDelinquencies                               -0.088950
# AmountDelinquent                                    0.006080
# DelinquenciesLast7Years                            -0.097849
# RevolvingCreditBalance                              0.149789
# AvailableBankcardCredit                             0.158976
# TradesNeverDelinquent (percentage)                  0.197618
# DebtToIncomeRatio                                   0.007388
# StatedMonthlyIncome                                 0.267711
# ProsperPrincipalBorrowed                            1.000000
# LoanOriginalAmount                                  0.382268
# MonthlyLoanPayment                                  0.339724
# LP_CustomerPayments                                 0.101672
# LP_CustomerPrincipalPayments                        0.103585
# LP_InterestandFees                                  0.047917
# Investors                                           0.143124
# Credit_Score_Avg                                    0.231863
# Annual_Income                                       0.267711
#
#                                     LoanOriginalAmount  MonthlyLoanPayment  \
# Term                                          0.338927            0.091026
# BorrowerAPR                                  -0.322887           -0.226653
# BorrowerRate                                 -0.328960           -0.244742
# LenderYield                                  -0.328455           -0.244214
# IsBorrowerHomeowner                           0.206787            0.179703
# CreditScoreRangeLower                         0.340874            0.292532
# CreditScoreRangeUpper                         0.340874            0.292532
# CurrentCreditLines                            0.201383            0.186922
# OpenCreditLines                               0.223681            0.205010
# TotalCreditLinespast7years                    0.145012            0.134829
# CurrentDelinquencies                         -0.172139           -0.158558
# AmountDelinquent                             -0.038756           -0.029638
# DelinquenciesLast7Years                      -0.136667           -0.121247
# RevolvingCreditBalance                        0.190879            0.193021
# AvailableBankcardCredit                       0.229866            0.196238
# TradesNeverDelinquent (percentage)            0.252534            0.220534
# DebtToIncomeRatio                             0.010112            0.027598
# StatedMonthlyIncome                           0.201259            0.196830
# ProsperPrincipalBorrowed                      0.382268            0.339724
# LoanOriginalAmount                            1.000000            0.931984
# MonthlyLoanPayment                            0.931984            1.000000
# LP_CustomerPayments                           0.364831            0.425351
# LP_CustomerPrincipalPayments                  0.322965            0.387200
# LP_InterestandFees                            0.366359            0.390476
# Investors                                     0.380093            0.387409
# Credit_Score_Avg                              0.340874            0.292532
# Annual_Income                                 0.201259            0.196830
#
#                                     LP_CustomerPayments  \
# Term                                          -0.069696
# BorrowerAPR                                   -0.111350
# BorrowerRate                                  -0.081055
# LenderYield                                   -0.079052
# IsBorrowerHomeowner                            0.094572
# CreditScoreRangeLower                          0.210125
# CreditScoreRangeUpper                          0.210125
# CurrentCreditLines                             0.022195
# OpenCreditLines                                0.003471
# TotalCreditLinespast7years                     0.017492
# CurrentDelinquencies                          -0.076932
# AmountDelinquent                              -0.015314
# DelinquenciesLast7Years                       -0.076597
# RevolvingCreditBalance                         0.079952
# AvailableBankcardCredit                        0.127857
# TradesNeverDelinquent (percentage)             0.055043
# DebtToIncomeRatio                              0.021246
# StatedMonthlyIncome                            0.085729
# ProsperPrincipalBorrowed                       0.101672
# LoanOriginalAmount                             0.364831
# MonthlyLoanPayment                             0.425351
# LP_CustomerPayments                            1.000000
# LP_CustomerPrincipalPayments                   0.977430
# LP_InterestandFees                             0.687189
# Investors                                      0.562607
# Credit_Score_Avg                               0.210125
# Annual_Income                                  0.085729
#
#                                     LP_CustomerPrincipalPayments  \
# Term                                                   -0.128255
# BorrowerAPR                                            -0.180445
# BorrowerRate                                           -0.153722
# LenderYield                                            -0.151563
# IsBorrowerHomeowner                                     0.089186
# CreditScoreRangeLower                                   0.225058
# CreditScoreRangeUpper                                   0.225058
# CurrentCreditLines                                      0.018597
# OpenCreditLines                                        -0.000480
# TotalCreditLinespast7years                              0.010455
# CurrentDelinquencies                                   -0.078224
# AmountDelinquent                                       -0.018724
# DelinquenciesLast7Years                                -0.082582
# RevolvingCreditBalance                                  0.070804
# AvailableBankcardCredit                                 0.152325
# TradesNeverDelinquent (percentage)                      0.067109
# DebtToIncomeRatio                                       0.011279
# StatedMonthlyIncome                                     0.082557
# ProsperPrincipalBorrowed                                0.103585
# LoanOriginalAmount                                      0.322965
# MonthlyLoanPayment                                      0.387200
# LP_CustomerPayments                                     0.977430
# LP_CustomerPrincipalPayments                            1.000000
# LP_InterestandFees                                      0.518203
# Investors                                               0.551215
# Credit_Score_Avg                                        0.225058
# Annual_Income                                           0.082557
#
#                                     LP_InterestandFees  Investors  \
# Term                                          0.158890  -0.045137
# BorrowerAPR                                   0.169726  -0.307606
# BorrowerRate                                  0.200479  -0.274217
# LenderYield                                   0.201162  -0.274174
# IsBorrowerHomeowner                           0.076168   0.125093
# CreditScoreRangeLower                         0.076810   0.271350
# CreditScoreRangeUpper                         0.076810   0.271350
# CurrentCreditLines                            0.025585   0.039449
# OpenCreditLines                               0.015574   0.025211
# TotalCreditLinespast7years                    0.034835   0.008226
# CurrentDelinquencies                         -0.042454  -0.087091
# AmountDelinquent                              0.002477  -0.027039
# DelinquenciesLast7Years                      -0.026103  -0.105479
# RevolvingCreditBalance                        0.079139   0.072185
# AvailableBankcardCredit                      -0.007003   0.207695
# TradesNeverDelinquent (percentage)           -0.008248   0.099087
# DebtToIncomeRatio                             0.047804   0.004095
# StatedMonthlyIncome                           0.063166   0.076244
# ProsperPrincipalBorrowed                      0.047917   0.143124
# LoanOriginalAmount                            0.366359   0.380093
# MonthlyLoanPayment                            0.390476   0.387409
# LP_CustomerPayments                           0.687189   0.562607
# LP_CustomerPrincipalPayments                  0.518203   0.551215
# LP_InterestandFees                            1.000000   0.382127
# Investors                                     0.382127   1.000000
# Credit_Score_Avg                              0.076810   0.271350
# Annual_Income                                 0.063166   0.076244
#
#                                     Credit_Score_Avg  Annual_Income
# Term                                        0.126263       0.028479
# BorrowerAPR                                -0.429707      -0.082338
# BorrowerRate                               -0.461567      -0.088982
# LenderYield                                -0.454350      -0.088208
# IsBorrowerHomeowner                         0.293516       0.140051
# CreditScoreRangeLower                       1.000000       0.107901
# CreditScoreRangeUpper                       1.000000       0.107901
# CurrentCreditLines                          0.142092       0.143329
# OpenCreditLines                             0.148210       0.143035
# TotalCreditLinespast7years                  0.108707       0.149552
# CurrentDelinquencies                       -0.368450      -0.038835
# AmountDelinquent                           -0.065849       0.008662
# DelinquenciesLast7Years                    -0.251219      -0.025805
# RevolvingCreditBalance                      0.088848       0.194898
# AvailableBankcardCredit                     0.453257       0.111869
# TradesNeverDelinquent (percentage)          0.468899       0.061633
# DebtToIncomeRatio                          -0.013169      -0.122659
# StatedMonthlyIncome                         0.107901       1.000000
# ProsperPrincipalBorrowed                    0.231863       0.267711
# LoanOriginalAmount                          0.340874       0.201259
# MonthlyLoanPayment                          0.292532       0.196830
# LP_CustomerPayments                         0.210125       0.085729
# LP_CustomerPrincipalPayments                0.225058       0.082557
# LP_InterestandFees                          0.076810       0.063166
# Investors                                   0.271350       0.076244
# Credit_Score_Avg                            1.000000       0.107901
# Annual_Income                               0.107901       1.000000

# %%
val_list = test_corr.values.tolist()
val_list = [item for sublist in val_list for item in sublist]
x_list = test_corr.index.tolist()
y_list = np.repeat(index_list,27)
x_list = x_list * 27

# %%
corr_dict = {'Value': val_list, 'x_axis': y_list, 'y_axis': x_list}
df_corr = pd.DataFrame.from_dict(corr_dict)

# %%
#df_corr.sample(10)
df_corr.shape
# Out:
# (20, 3)

# %% [markdown]
# ### Remove Rows from New Dataframe
# Removing rows that are very similar and would have a very high correlation because they are closely related such as upper and lower credit score ranges, principal payments and customer principal payments, and borrower rate and borrower APR.

# %%
df_corr = df_corr.query('Value != 1')
df_corr = df_corr.query('abs(Value) >= 0.3')
df_corr = df_corr.query('x_axis != "CreditScoreRangeLower"')
df_corr = df_corr.query('x_axis != "CreditScoreRangeUpper"')
df_corr = df_corr.query('y_axis != "CreditScoreRangeLower"')
df_corr = df_corr.query('y_axis != "CreditScoreRangeUpper"')

df_corr = df_corr.query('y_axis != "CreditScoreRangeUpper" and x_axis != "CreditScoreRangeLower"')
df_corr = df_corr.query('y_axis != "CreditScoreRangeLower" and x_axis != "CreditScoreRangeUpper"')

df_corr = df_corr.query('y_axis != "BorrowerRate" and x_axis != "BorrowerAPR"')
df_corr = df_corr.query('y_axis != "BorrowerAPR" and x_axis != "BorrowerRate"')

df_corr = df_corr.query('y_axis != "StatedMonthlyIncome" and x_axis != "Annual_Income"')
df_corr = df_corr.query('y_axis != "Annual_Income" and x_axis != "StatedMonthlyIncome"')

df_corr = df_corr.query('y_axis != "LP_CustomerPayments" and x_axis != "LP_CustomerPrincipalPayments"')
df_corr = df_corr.query('y_axis != "LP_CustomerPrincipalPayments" and x_axis != "LP_CustomerPayments"')

df_corr = df_corr.query('y_axis != "OpenCreditLines" and x_axis != "CurrentCreditLines"')
df_corr = df_corr.query('y_axis != "CurrentCreditLines" and x_axis != "OpenCreditLines"')

df_corr.drop_duplicates(subset = "Value", keep = 'first', inplace = True)

df_corr['Value'] = df_corr['Value'].abs()
df_corr = df_corr.sort_values('Value', ascending = False)
#df_corr.reset_index(inplace = True)
print(df_corr.shape)

df_corr
#df_corr.to_csv('Correlation_Values.csv')
# Out:
# (20, 3)
#        Value                              x_axis  \
# 0   0.931984                  LoanOriginalAmount
# 1   0.516443             DelinquenciesLast7Years
# 2   0.468899  TradesNeverDelinquent (percentage)
# 3   0.458761                CurrentDelinquencies
# 4   0.454350                         LenderYield
# 5   0.453257             AvailableBankcardCredit
# 6   0.390476                  MonthlyLoanPayment
# 7   0.387409                  MonthlyLoanPayment
# 8   0.382268            ProsperPrincipalBorrowed
# 9   0.382127                  LP_InterestandFees
# 10  0.380093                  LoanOriginalAmount
# 11  0.377777                CurrentDelinquencies
# 12  0.368450                CurrentDelinquencies
# 13  0.366359                  LoanOriginalAmount
# 14  0.340939                         LenderYield
# 15  0.340874                  LoanOriginalAmount
# 16  0.340549                CurrentDelinquencies
# 17  0.339724            ProsperPrincipalBorrowed
# 18  0.338927                                Term
# 19  0.328455                         LenderYield
#
#                                 y_axis
# 0                   MonthlyLoanPayment
# 1   TradesNeverDelinquent (percentage)
# 2                     Credit_Score_Avg
# 3   TradesNeverDelinquent (percentage)
# 4                     Credit_Score_Avg
# 5                     Credit_Score_Avg
# 6                   LP_InterestandFees
# 7                            Investors
# 8                   LoanOriginalAmount
# 9                            Investors
# 10                           Investors
# 11             DelinquenciesLast7Years
# 12                    Credit_Score_Avg
# 13                  LP_InterestandFees
# 14             AvailableBankcardCredit
# 15                    Credit_Score_Avg
# 16                    AmountDelinquent
# 17                  MonthlyLoanPayment
# 18                  LoanOriginalAmount
# 19                  LoanOriginalAmount

# %%
#Saving the Dataframe to a csv file so the data can be used in the next notebook
df_corr.to_csv('Correlation_Values.csv')

# %%
# Saving the dataframe as a 
df.to_csv('Focused_Bank_Info.csv')
